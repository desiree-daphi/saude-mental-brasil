# %% [markdown]
# ## Fontes de Dados
#
# ### PNS 2019 — IBGE
# - **Nome:** Pesquisa Nacional de Saúde 2019
# - **Órgão:** IBGE em parceria com o Ministério da Saúde
# - **Acesso:** https://www.ibge.gov.br/estatisticas/sociais/saude/9160-pesquisa-nacional-de-saude.html
# - **Data de download:** 26/06/2026
# - **Arquivo salvo como:** data/raw/pns2019_microdados.csv
#
# ### DATASUS — SIH/SUS
# - **Nome:** Sistema de Informações Hospitalares do SUS
# - **Órgão:** Ministério da Saúde / DATASUS
# - **Acesso:** https://datasus.saude.gov.br/informacoes-de-saude-tabnet/
# - **Período coberto:** 2015–2024
# - **Filtro aplicado:** Capítulo CID-10 / Transtornos mentais (F00–F99)
# - **Data de download:** 26/06/2026
# - **Arquivo salvo como:** data/raw/datasus_internacoes_bruto.csv

# %%
# Intalando bibliotecas
# !pip install pandas matplotlib seaborn openpyxl jupyterinstall pandas
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement jupyterinstall (from versions: none)
# ERROR: No matching distribution found for jupyterinstall

# %%
import pandas as pd
import os

#Listar arquivos na pasta raw
print("Aquivos disponíveis em data/raw/:")
for arquivos in os.listdir("../data/raw/"):
    print(arquivos)
# Out:
# Aquivos disponíveis em data/raw/:
# datasus_internacoes_bruto.csv
# pns2019_microdados.csv
